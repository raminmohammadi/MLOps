# %%
import random

def get_5_students(student_list):
    
    selected_students = random.sample(student_list, 6)
    
    # Remove selected students from the original list
    student_list = [student for student in student_list if student not in selected_students]
    
    # Return the selected students and updated list
    return selected_students, student_list

# %%
import pandas as pd

# %%
# df = pd.read_csv('2024-10-02T1805_Grades-IE7374.17974.202510.csv')
df = pd.read_csv('2024-09-23T1953_Grades-IE7374.20720.202510.csv')

# %%
df.head()
# Out:
#                                Student        ID SIS User ID SIS Login ID  \
# 0                      Points Possible       NaN         NaN          NaN
# 1                     Acharya, Mrudula  206440.0  002769383S   002769383S
# 2  Addaganti, Venkata Subbarao Shirish  217259.0  002728162S   002728162S
# 3                  Ala, Venkata Nithya  218378.0  002768082S   002768082S
# 4                 Alagesan, Aishwariya  273954.0  002818973S   002818973S
#
#                                              Section  \
# 0                                                NaN
# 1  IE7374 20720 Machine Learning Operations SEC 0...
# 2  IE7374 20720 Machine Learning Operations SEC 0...
# 3  IE7374 20720 Machine Learning Operations SEC 0...
# 4  IE7374 20720 Machine Learning Operations SEC 0...
#
#    Project Scoping (2432315)  In Class Assignments (2432313)  \
# 0                      100.0                            10.0
# 1                        NaN                             NaN
# ...

# %%
students = list(df.Student)

# %%
selected, updated_list = get_5_students(students)

print("Selected students:", selected)
# Out:
# Selected students: ['Gajjar, Henil', 'Saxena, Samarth', 'Moorthy, Hashwanth', 'Alagesan, Aishwariya', 'Samanta, Risa', 'Gnanasekar, Oviya']
